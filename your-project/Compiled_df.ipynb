# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Importing all the datasets separately

# %%
World_happiness = pd.read_csv("Data_project/World_happiness/2018.csv")

# %%
World_happiness
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
Migration_per_country = pd.read_csv("Data_project/Migration_per_country.csv")

# %%
#Migration_per_country #Needs fixing
# Out:
#         CO2 Country of birth/nationality  VAR  \
# 0       AFG                  Afghanistan  B11
# 1       AFG                  Afghanistan  B11
# 2       AFG                  Afghanistan  B11
# 3       AFG                  Afghanistan  B11
# 4       AFG                  Afghanistan  B11
# ...     ...                          ...  ...
# 477771  MKD              North Macedonia  B12
# 477772  MRT                   Mauritania  B12
# 477773  QAT                        Qatar  B12
# 477774   NS                   Not stated  B12
# 477775   NS                   Not stated  B14
#
#                                                  Variable  GEN Gender  COU  \
# 0            Inflows of foreign population by nationality  TOT  Total  AUS
# 1            Inflows of foreign population by nationality  TOT  Total  AUS
# 2            Inflows of foreign population by nationality  TOT  Total  AUS
# 3            Inflows of foreign population by nationality  TOT  Total  AUS
# ...

# %%
Global_travel = pd.read_excel("Data_project/Global_travel/global_travel_inbound.xls")

# %%
# Global_travel Needs fixing

# %%
Human_dev_index = pd.read_csv("Data_project/Human_Development.csv")

# %%
Human_dev_index #to be animated
# Out:
#      HDI Rank                              Country   1990   1991   1992  \
# 0         168                          Afghanistan    NaN    NaN    NaN
# 1          68                              Albania  0.645  0.626  0.610
# 2          85                              Algeria  0.577  0.581  0.587
# 3          35                              Andorra    NaN    NaN    NaN
# 4         147                               Angola    NaN    NaN    NaN
# ..        ...                                  ...    ...    ...    ...
# 184        78   Venezuela (Bolivarian Republic of)  0.634  0.644  0.651
# 185       116                             Viet Nam  0.475  0.484  0.496
# 186       178                                Yemen  0.399  0.403  0.405
# 187       144                               Zambia  0.401  0.402  0.403
# 188       156                             Zimbabwe  0.491  0.494  0.481
#
#       1993   1994   1995   1996   1997  ...   2008   2009   2010   2011  \
# ...

# %%
Human_fredom_index = pd.read_csv("Data_project/Human_fredom_index/hfi_cc_2018.csv")

# %%
Human_fredom_index # ony up to 2016 could be animated or could be compared with 2016 happiness data
# Out:
#       year ISO_code    countries                         region  \
# 0     2016      ALB      Albania                 Eastern Europe
# 1     2016      DZA      Algeria     Middle East & North Africa
# 2     2016      AGO       Angola             Sub-Saharan Africa
# 3     2016      ARG    Argentina  Latin America & the Caribbean
# 4     2016      ARM      Armenia        Caucasus & Central Asia
# ...    ...      ...          ...                            ...
# 1453  2008      VEN    Venezuela  Latin America & the Caribbean
# 1454  2008      VNM      Vietnam                     South Asia
# 1455  2008      YEM  Yemen, Rep.     Middle East & North Africa
# 1456  2008      ZMB       Zambia             Sub-Saharan Africa
# 1457  2008      ZWE     Zimbabwe             Sub-Saharan Africa
#
#       pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  \
# 0              6.661503      4.547244         4.666508  5.291752
# ...

# %%
Income_per_country = pd.read_excel("Data_project/Income_by_Country.xlsx")

# %%
#Income_per_country #Needs to grab year # year progression could be interesting to compare with development

# %%
Obesity = pd.read_csv("Data_project/Obesity_data/data.csv")

# %%
#Obesity Needs cleaning cleaned data is usless

# %%
Population = pd.read_csv("Data_project/population_by_country_2020.csv")

# %%
#Population Its for 2020 its a bit usless

# %%
Suicide_rates = pd.read_csv("Data_project/Suicide_rates.csv")

# %%
# Suicide_rates Needs a lot of work to adjust yeares and countries

# %%
Taxes = pd.read_csv("Data_project/taxes.csv")

# %%
# Taxes · needs a lot of work to adjust can maybe done in website

# %%
Cont = pd.read_csv("Data_project/countryContinent.csv", encoding='latin-1')

# %%
continents = Cont.drop(columns=["code_2", "code_3", "country_code", "iso_3166_2", "region_code", "sub_region_code"])

continents.to_csv("Data_project/cont.csv")
