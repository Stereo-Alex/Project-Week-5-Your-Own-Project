# %% [markdown]
# # Workspace, fixing up the data

# %%
# We want to merge income per country taxes and happiness 
import pandas as pd
import numpy as np

# %%
World_happiness = pd.read_csv("Data_project/World_happiness/2018.csv")
GDP_per_capita = pd.read_excel("Data_project/GDP_per_capita.xlsx")
Taxes = pd.read_csv("Data_project/taxes4.csv")

# %%
Taxes_clean =  Taxes.drop(columns = ["COU", "TAX", "Income Tax", "YEA", "Unit Code", "Unit", "PowerCode Code", "Reference Period Code", "Reference Period","PowerCode", "Flag Codes",  "Flags"])

# %%
World_happiness.rename({"Country or region" : "Country"}, axis="columns",inplace=True)
#World_happiness

# %%
GDP_per_capita.rename({2018 : "GDP_per_capita"}, axis="columns",inplace=True)
GDP_per_capita
# Out:
#                                                Country GDP_per_capita
# 0                                          Afghanistan           1735
# 1                                              Albania          12306
# 2                                              Algeria          13886
# 3                                               Angola           5725
# 4                                  Antigua and Barbuda          23768
# ..                                                 ...            ...
# 204                                 Sub-Saharan Africa           3552
# 205                          Least Developed Countries           2688
# 206                     Small Island Developing States          18086
# 207  Organization for Economic Co-operation and Dev...          40492
# 208                                              World          15893
#
# [209 rows x 2 columns]

# %%
merge1 = World_happiness.merge(Taxes_clean, how='left', on="Country")

# %%
Income_per_country
# Out:
#                                                Country   1990   1991   1992  \
# 0                                          Afghanistan  0.466  0.440  0.431
# 1                                              Albania  0.572  0.521  0.506
# 2                                              Algeria  0.695  0.687  0.687
# 3                                              Andorra  0.936  0.934  0.929
# 4                                               Angola  0.562  0.576  0.431
# ..                                                 ...    ...    ...    ...
# 203                                 Sub-Saharan Africa  0.494  0.491  0.483
# 204                          Least Developed Countries  0.395  0.392  0.383
# 205                     Small Island Developing States  0.640  0.642  0.646
# 206  Organization for Economic Co-operation and Dev...  0.846  0.846  0.848
# 207                                              World  0.679  0.678  0.677
#
# ...

# %%
merge2 = merge1.merge(GDP_per_capita, how='left', on="Country")

# %%
merge2
# Out:
#      Overall rank                   Country  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %% [markdown]
# # Cleaning up the names of merge 2 and saving it for graphing

# %%
merge2.rename({"Score" : "Happiness Score", "Value" : "Maximun Personal Income Tax"}, axis="columns",inplace=True)
merge2.drop(columns=["Year"])
# Out:
#      Overall rank                   Country  Happiness Score  GDP per capita  \
# 0               1                   Finland            7.632           1.305
# 1               2                    Norway            7.594           1.456
# 2               3                   Denmark            7.555           1.351
# 3               4                   Iceland            7.495           1.343
# 4               5               Switzerland            7.487           1.420
# ..            ...                       ...              ...             ...
# 151           152                     Yemen            3.355           0.442
# 152           153                  Tanzania            3.303           0.455
# 153           154               South Sudan            3.254           0.337
# 154           155  Central African Republic            3.083           0.024
# 155           156                   Burundi            2.905           0.091
#
# ...

# %%
merge2.to_csv("Data_project/Happiness_gdp_taxes.csv")
