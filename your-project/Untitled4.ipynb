# %% [markdown]
# # Animated plots

# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import seaborn as sns
import plotly.express as px
import cufflinks as cf
import plotly.graph_objects as go

# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
Human_dev_index = pd.read_csv("Data_project/Human_Development.csv")

# %%
Human_fredom_index = pd.read_csv("Data_project/Human_fredom_index/hfi_cc_2018.csv")

# %%
df = Human_fredom_index

# %%
df = df.fillna(0)

df
# Out:
#       year ISO_code    countries                         region  \
# 0     2016      ALB      Albania                 Eastern Europe
# 1     2016      DZA      Algeria     Middle East & North Africa
# 2     2016      AGO       Angola             Sub-Saharan Africa
# 3     2016      ARG    Argentina  Latin America & the Caribbean
# 4     2016      ARM      Armenia        Caucasus & Central Asia
# ...    ...      ...          ...                            ...
# 1453  2008      VEN    Venezuela  Latin America & the Caribbean
# 1454  2008      VNM      Vietnam                     South Asia
# 1455  2008      YEM  Yemen, Rep.     Middle East & North Africa
# 1456  2008      ZMB       Zambia             Sub-Saharan Africa
# 1457  2008      ZWE     Zimbabwe             Sub-Saharan Africa
#
#       pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  \
# 0              6.661503      4.547244         4.666508  5.291752
# 1              0.000000      0.000000         0.000000  3.819566
# 2              0.000000      0.000000         0.000000  3.451814
# 3              7.098483      5.791960         4.343930  5.744791
# 4              0.000000      0.000000         0.000000  5.003205
# ...                 ...           ...              ...       ...
# 1453           3.000000      3.781688         2.369239  3.100000
# 1454           6.666667      4.349101         5.694847  5.600000
# 1455           0.000000      0.000000         0.000000  0.000000
# 1456           4.800000      4.578003         3.688652  4.400000
# 1457           2.700000      3.991582         4.327660  3.700000
#
#       pf_ss_homicide  pf_ss_disappearances_disap  ...  \
# 0           8.920429                        10.0  ...
# 1           9.456254                        10.0  ...
# 2           8.060260                         5.0  ...
# 3           7.622974                        10.0  ...
# 4           8.808750                        10.0  ...
# ...              ...                         ...  ...
# 1453        0.000000                        10.0  ...
# 1454        9.496239                         5.0  ...
# 1455        0.000000                         0.0  ...
# 1456        7.878084                        10.0  ...
# 1457        7.981019                         0.0  ...
#
#       ef_regulation_business_bribes  ef_regulation_business_licensing  \
# 0                          4.050196                          7.324582
# 1                          3.765515                          8.523503
# 2                          1.945540                          8.096776
# 3                          3.260044                          5.253411
# 4                          4.575152                          9.319612
# ...                             ...                               ...
# 1453                       2.784695                          4.578318
# 1454                       3.626593                          7.306074
# 1455                       0.000000                          0.000000
# 1456                       4.585391                          5.124436
# 1457                       4.423866                          0.000000
#
#       ef_regulation_business_compliance  ef_regulation_business  \
# 0                              7.074366                6.705863
# 1                              7.029528                5.676956
# 2                              6.782923                4.930271
# 3                              6.508295                5.535831
# 4                              6.491481                6.797530
# ...                                 ...                     ...
# 1453                           0.315142                2.864160
# 1454                           0.000000                4.574683
# 1455                           0.000000                0.000000
# 1456                           8.520369                6.681524
# 1457                           6.973482                3.369110
#
#       ef_regulation  ef_score  ef_rank  hf_score  hf_rank  hf_quartile
# 0          6.906901      7.54     34.0  7.568140     48.0          2.0
# 1          5.268992      4.99    159.0  5.135886    155.0          4.0
# 2          5.518500      5.17    155.0  5.640662    142.0          4.0
# 3          5.369019      4.84    160.0  6.469848    107.0          3.0
# 4          7.378069      7.57     29.0  7.241402     57.0          2.0
# ...             ...       ...      ...       ...      ...          ...
# 1453       4.666936      4.22    140.0  5.257879    136.0          4.0
# 1454       6.307577      6.19    103.0  6.420206    106.0          3.0
# 1455       0.000000      0.00      0.0  0.000000      0.0          0.0
# 1456       6.722175      7.15     57.0  6.647724     95.0          3.0
# 1457       4.488892      4.55    138.0  4.935571    140.0          4.0
#
# [1458 rows x 123 columns]

# %%
df.year = df.year[::-1]
df
# Out:
#       year ISO_code    countries                         region  \
# 0     2016      ALB      Albania                 Eastern Europe
# 1     2016      DZA      Algeria     Middle East & North Africa
# 2     2016      AGO       Angola             Sub-Saharan Africa
# 3     2016      ARG    Argentina  Latin America & the Caribbean
# 4     2016      ARM      Armenia        Caucasus & Central Asia
# ...    ...      ...          ...                            ...
# 1453  2008      VEN    Venezuela  Latin America & the Caribbean
# 1454  2008      VNM      Vietnam                     South Asia
# 1455  2008      YEM  Yemen, Rep.     Middle East & North Africa
# 1456  2008      ZMB       Zambia             Sub-Saharan Africa
# 1457  2008      ZWE     Zimbabwe             Sub-Saharan Africa
#
#       pf_rol_procedural  pf_rol_civil  pf_rol_criminal    pf_rol  \
# 0              6.661503      4.547244         4.666508  5.291752
# 1              0.000000      0.000000         0.000000  3.819566
# 2              0.000000      0.000000         0.000000  3.451814
# 3              7.098483      5.791960         4.343930  5.744791
# 4              0.000000      0.000000         0.000000  5.003205
# ...                 ...           ...              ...       ...
# 1453           3.000000      3.781688         2.369239  3.100000
# 1454           6.666667      4.349101         5.694847  5.600000
# 1455           0.000000      0.000000         0.000000  0.000000
# 1456           4.800000      4.578003         3.688652  4.400000
# 1457           2.700000      3.991582         4.327660  3.700000
#
#       pf_ss_homicide  pf_ss_disappearances_disap  ...  \
# 0           8.920429                        10.0  ...
# 1           9.456254                        10.0  ...
# 2           8.060260                         5.0  ...
# 3           7.622974                        10.0  ...
# 4           8.808750                        10.0  ...
# ...              ...                         ...  ...
# 1453        0.000000                        10.0  ...
# 1454        9.496239                         5.0  ...
# 1455        0.000000                         0.0  ...
# 1456        7.878084                        10.0  ...
# 1457        7.981019                         0.0  ...
#
#       ef_regulation_business_bribes  ef_regulation_business_licensing  \
# 0                          4.050196                          7.324582
# 1                          3.765515                          8.523503
# 2                          1.945540                          8.096776
# 3                          3.260044                          5.253411
# 4                          4.575152                          9.319612
# ...                             ...                               ...
# 1453                       2.784695                          4.578318
# 1454                       3.626593                          7.306074
# 1455                       0.000000                          0.000000
# 1456                       4.585391                          5.124436
# 1457                       4.423866                          0.000000
#
#       ef_regulation_business_compliance  ef_regulation_business  \
# 0                              7.074366                6.705863
# 1                              7.029528                5.676956
# 2                              6.782923                4.930271
# 3                              6.508295                5.535831
# 4                              6.491481                6.797530
# ...                                 ...                     ...
# 1453                           0.315142                2.864160
# 1454                           0.000000                4.574683
# 1455                           0.000000                0.000000
# 1456                           8.520369                6.681524
# 1457                           6.973482                3.369110
#
#       ef_regulation  ef_score  ef_rank  hf_score  hf_rank  hf_quartile
# 0          6.906901      7.54     34.0  7.568140     48.0          2.0
# 1          5.268992      4.99    159.0  5.135886    155.0          4.0
# 2          5.518500      5.17    155.0  5.640662    142.0          4.0
# 3          5.369019      4.84    160.0  6.469848    107.0          3.0
# 4          7.378069      7.57     29.0  7.241402     57.0          2.0
# ...             ...       ...      ...       ...      ...          ...
# 1453       4.666936      4.22    140.0  5.257879    136.0          4.0
# 1454       6.307577      6.19    103.0  6.420206    106.0          3.0
# 1455       0.000000      0.00      0.0  0.000000      0.0          0.0
# 1456       6.722175      7.15     57.0  6.647724     95.0          3.0
# 1457       4.488892      4.55    138.0  4.935571    140.0          4.0
#
# [1458 rows x 123 columns]

# %%
df = df.dropna(0)

px.scatter(df, x="ef_score", y="hf_rank", 
          animation_frame="year",
          animation_group = "countries",
          color="region", hover_name="countries",
          log_x=True)
# Out:
# <div>                            <div id="8c7595da-c7cd-464e-bf5c-ab835da26abc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c7595da-c7cd-464e-bf5c-ab835da26abc")) {                    Plotly.newPlot(                        "8c7595da-c7cd-464e-bf5c-ab835da26abc",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>region=Eastern Europe<br>year=2016<br>ef_score=%{x}<br>hf_rank=%{y}<extra></extra>", "hovertext": ["Albania", "Belarus", "Bosnia and Herzegovina", "Bulgaria", "Croatia", "Cyprus", "Czech Rep.", "Estonia", "Greece", "Hungary", "Latvia", "Lithuania", "Macedonia", "Moldova", "Montenegro", "Poland", "Romania", "Russia", "Serbia", "Slovak Rep.", "Slovenia", "Ukraine"], "ids": ["Albania", "Belarus", "Bosnia and Herzegovina", "Bulgaria", "Croatia", "Cyprus", "Czech Rep.", "Estonia", "Greece", "Hungary", "Latvia", "Lithuania", "Macedonia", "Moldova", "Montenegro", "Poland", "Romania", "Russia", "Serbia", "Slovak Rep.", "Slovenia", "Ukraine"], "legendgroup": "Eastern Europe", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Eastern Europe", "orientation": "v", "showlegend": true, "type": "scatter", "x": [7.54, 6.23, 6.6, 7.41, 6.96, 7.71, 7.56, 7.86, 6.46, 7.22, 7.64, 7.86, 7.13, 6.64, 7.04, 7.27, 7.69, 6.83, 6.85, 7.3, 7.05, 5.98], "xaxis": "x", "y": [48.0, 128.0, 59.0, 41.0, 44.0, 30.0, 21.0, 14.0, 61.0, 42.0, 23.0, 20.0, 56.0, 75.0, 52.0, 39.0, 24.0, 119.0, 51.0, 36.0, 35.0, 118.0], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>region=Middle East & North Africa<br>year=2016<br>ef_score=%{x}<br>hf_rank=%{y}<extra></extra>", "hovertext": ["Algeria", "Bahrain", "Egypt", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Libya", "Morocco", "Oman", "Qatar", "Saudi Arabia", "Syria", "Tunisia", "Turkey", "United Arab Emirates", "Yemen, Rep."], "ids": ["Algeria", "Bahrain", "Egypt", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Libya", "Morocco", "Oman", "Qatar", "Saudi Arabia", "Syria", "Tunisia", "Turkey", "United Arab Emirates", "Yemen, Rep."], "legendgroup": "Middle East & North Africa", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Middle East & North Africa", "orientation": "v", "showlegend": true, "type": "scatter", "x": [4.99, 7.56, 5.72, 6.03, 5.4, 7.49, 7.46, 6.75, 6.99, 4.74, 6.37, 6.76, 7.49, 6.52, 5.02, 6.29, 6.84, 7.5, 6.34], "xaxis": "x", "y": [155.0, 75.0, 156.0, 153.0, 159.0, 49.0, 75.0, 124.0, 95.0, 158.0, 127.0, 129.0, 103.0, 146.0, 162.0, 109.0, 107.0, 117.0, 160.0], "yaxis": "y"}, {"hovertemplate": "<b>%{hovertext}</b><br><br>region=Sub-Saharan Africa<br>year=2016<br>ef_score=%{x}<br>hf_rank=%{y}<extra></extra>", "hovertext": ["Angola", "Benin", "Botswana", "Burkina Faso", "Burundi", "Cameroon", "Cape Verde", "Central Afr. Rep.", "Chad", "Congo, Dem. R.", "Congo, Rep. Of", "Cote d'Ivoire", "Ethiopia", "Gabon", "Gambia, The", "Ghana", "Guinea", "Guinea-Bissau", "Kenya", "Lesotho", "Liberia", "Madagascar", "Malawi", "Mali", "Mauritania", "Mauritius", "Mozambique", "Namibia", "Niger", "Nigeria", "Rwanda", "Senegal", "Seychelles", "Sierra Leone", "South Africa", "Sudan", "Swaziland", "Tanzania", "Togo", "Uganda", "Zambia", "Zimbabwe"], "ids": ["Angola", "Benin", "Botswana", "Burkina Faso", "Burundi", "Cameroon", "Cape Verde", "Central Afr. Rep.", "Chad", "Congo, Dem. R.", "Congo, Rep. Of", "Cote d'Ivoire", "Ethiopia", "Gabon", "Gambia, The", "Ghana", "Guinea", "Guinea-Bissau", "Kenya", "Lesotho", "Liberia", "Madagascar", "Malawi", "Mali", "Mauritania", "Mauritius", "Mozambique", "Namibia", "Niger", "Nigeria", "Rwanda", "Senegal", "Seychelles", "Sierra Leone", "South Africa", "Sudan", "Swaziland", "Tanzania", "Togo", "Uganda", "Zambia", "Zimbabwe"], "legendgroup ...

# %%
Human_dev_index = pd.read_csv("Data_project/Human_Development.csv")
